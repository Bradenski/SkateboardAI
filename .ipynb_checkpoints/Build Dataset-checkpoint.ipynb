# %%
import os 
import glob
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
def get_clip_info(clip: str) -> list:
    '''
    Returns info on clip. Assumes order of trick_firstname-lastname_sw_slow_mo
    ''' 
    sw = False
    slowmo = False

    clip = clip.split('/')[-1].split('\\')[-1].split('.')[0].split('_')
    trick = clip[0]
    skater = clip[1]
    if len(clip) > 2: 
        if clip[2] == 'sw':
            sw = True
        if clip[2] == 'slow-mo': 
            slowmo = True
        elif len(clip) > 3:
            if clip[3] == 'slow-mo':
                slowmo = True
            

    return [trick, skater, sw, slowmo]

# %%
tricks_path = "C:/Users/Braden/Projects/SkateboardAI/skateboard-tricks/"
tricks_data = []

for clip in glob.glob(tricks_path + '/*'): 
#     print(clip)
#     print(get_clip_info(clip))
    entry = get_clip_info(clip)
    entry.append(clip)
    tricks_data.append(entry)      

tricks_data
# Out:
# [['360-flip',
#   'akihiko-gatangay',
#   False,
#   False,
#   'C:/Users/Braden/Projects/SkateboardAI/skateboard-tricks\\360-flip_akihiko-gatangay.mov'],
#  ['360-flip',
#   'andrew-reynolds',
#   False,
#   False,
#   'C:/Users/Braden/Projects/SkateboardAI/skateboard-tricks\\360-flip_andrew-reynolds.mov'],
#  ['360-flip',
#   'antwuan-dixon',
#   False,
#   False,
#   'C:/Users/Braden/Projects/SkateboardAI/skateboard-tricks\\360-flip_antwuan-dixon.mov'],
#  ['360-flip',
#   'braden-starcher',
#   False,
#   False,
#   'C:/Users/Braden/Projects/SkateboardAI/skateboard-tricks\\360-flip_braden-starcher.mp4'],
#  ['360-flip',
#   'braden-starcher',
#   False,
#   False,
#   'C:/Users/Braden/Projects/SkateboardAI/skateboard-tricks\\360-flip_braden-starcher_2.mp4'],
#  ['360-flip',
#   'hyun-kummer',
#   False,
#   False,
#   'C:/Users/Braden/Projects/SkateboardAI/skateboard-tricks\\360-flip_hyun-kummer.mov'],
#  ['360-flip',
#   'maurio-mccoy',
#   False,
#   False,
#   'C:/Users/Braden/Projects/SkateboardAI/skateboard-tricks\\360-flip_maurio-mccoy.mov'],
#  ['360-flip',
#   'maurio-mccoy',
#   False,
#   False,
#   'C:/Users/Braden/Projects/SkateboardAI/skateboard-tricks\\360-flip_maurio-mccoy_2.mov'],
#  ['360-flip',
#   'maurio-mccoy',
#   False,
#   False,
#   'C:/Users/Braden/Projects/SkateboardAI/skateboard-tricks\\360-flip_maurio-mccoy_3.mov'],
#  ['360-flip',
#   'maurio-mccoy',
#   False,
#   False,
#   'C:/Users/Braden/Projects/SkateboardAI/skateboard-tricks\\360-flip_maurio-mccoy_4.mov'],
#  ['360-flip',
#   'patrick-praman',
#   False,
#   False,
#   'C:/Users/Braden/Projects/SkateboardAI/skateboard-tricks\\360-flip_patrick-praman.mov'],
#  ['360-flip',
#   'stefan-janoski',
#   False,
#   False,
#   'C:/Users/Braden/Projects/SkateboardAI/skateboard-tricks\\360-flip_stefan-janoski.mov'],
#  ['360-flip',
#   'stefan-janoski',
#   False,
#   False,
#   'C:/Users/Braden/Projects/SkateboardAI/skateboard-tricks\\360-flip_stefan-janoski_2.mov'],
#  ['360-flip',
#   'stevie-williams',
#   False,
#   False,
#   'C:/Users/Braden/Projects/SkateboardAI/skateboard-tricks\\360-flip_stevie-williams.mov'],
#  ['360-flip',
#   'stevie-williams',
#   False,
#   False,
#   'C:/Users/Braden/Projects/SkateboardAI/skateboard-tricks\\360-flip_stevie-williams_2.mov'],
#  ['360-flip',
#   'stevie-williams',
#   True,
#   False,
#   'C:/Users/Braden/Projects/SkateboardAI/skateboard-tricks\\360-flip_stevie-williams_sw.mov'],
#  ['360-flip',
#   'unknown',
#   False,
#   False,
#   'C:/Users/Braden/Projects/SkateboardAI/skateboard-tricks\\360-flip_unknown.mov'],
#  ['bs-flip',
#   'akihiko-gatongay',
#   False,
#   False,
#   'C:/Users/Braden/Projects/SkateboardAI/skateboard-tricks\\bs-flip_akihiko-gatongay_2.mov'],
#  ['bs-flip',
#   'akihiko-gatongay',
#   False,
#   True,
#   'C:/Users/Braden/Projects/SkateboardAI/skateboard-tricks\\bs-flip_akihiko-gatongay_slow-mo.mov'],
#  ['bs-flip',
#   'ben-gore',
#   False,
#   False,
#   'C:/Users/Braden/Projects/SkateboardAI/skateboard-tricks\\bs-flip_ben-gore.mov'],
#  ['bs-flip',
#   'dylan-jaeb',
#   False,
#   True,
#   'C:/Users/Braden/Projects/SkateboardAI/skateboard-tricks\\bs-flip_dylan-jaeb_slow-mo.mov'],
#  ['bs-flip',
#   'eric-koston',
#   False,
#   False,
#   'C:/Users/Braden/Projects/SkateboardAI/skateboard-tricks\\bs-flip_eric-koston.mov'],
#  ['bs-flip',
#   'eric-koston',
#   False,
#   False,
#   'C:/Users/Braden/Projects/SkateboardAI/skateboard-tricks\\bs-flip_eric-koston_2.mov'],
#  ['bs-flip',
#   'erik-ellington',
#   True,
#   True,
#   'C:/Users/Braden/Projects/SkateboardAI/skateboard-tricks\\bs-flip_erik-ellington_sw_slow-mo.mov'],
#  ['bs-flip',
#   'karl-watson',
#   False,
#   False,
#   'C:/Users/Braden/Projects/SkateboardAI/skateboard-tricks\\bs-flip_karl-watson.mov'],
#  ['bs-flip',
#   'tony-hawk',
#   False,
#   False,
#   'C:/Users/Braden/Projects/SkateboardAI/skateboard-tricks\\bs-flip_tony-hawk.mov'],
#  ['crooked-grind',
#   'marcus-mcbride',
#   False,
#   False,
#   'C:/Users/Braden/Projects/SkateboardAI/skateboard-tricks\\crooked-grind_marcus-mcbride.mov'],
#  ['crooked-grind',
#   'paul-rodriguez',
#   False,
#   False,
#   'C:/Users/Braden/Projects/SkateboardAI/skateboard-tricks\\crooked-grind_paul-rodriguez.mov'],
#  ['crooked-grind',
#   'paul-rodriguez',
#   False,
#   False,
#   'C:/Users/Braden/Projects/SkateboardAI/skateboard-tricks\\crooked-grind_paul-rodriguez_2.mov'],
#  ['crooked-grind',
#   'paul-rodriguez',
#   False,
#   False,
#   'C:/Users/Braden/Projects/SkateboardAI/skateboard-tricks\\crooked-grind_paul-rodriguez_3.mov'],
#  ['crooked-grind',
#   'paul-rodriguez',
#   False,
#   True,
#   'C:/Users/Braden/Projects/SkateboardAI/skateboard-tricks\\crooked-grind_paul-rodriguez_slow-mo.mov'],
#  ['crooked-grind',
#   'paul-rodriguez',
#   False,
#   True,
#   'C:/Users/Braden/Projects/SkateboardAI/skateboard-tricks\\crooked-grind_paul-rodriguez_slow-mo_2.mov'],
#  ['crooked-grind',
#   'paul-rodriguez',
#   False,
#   True,
#   'C:/Users/Braden/Projects/SkateboardAI/skateboard-tricks\\crooked-grind_paul-rodriguez_slow-mo_3.mov'],
#  ['crooked-grind',
#   'paul-rodriguez',
#   False,
#   True,
#   'C:/Users/Braden/Projects/SkateboardAI/skateboard-tricks\\crooked-grind_paul-rodriguez_slow-mo_4.mov'],
#  ['crooked-grind',
#   'stevie-williams',
#   True,
#   False,
#   'C:/Users/Braden/Projects/SkateboardAI/skateboard-tricks\\crooked-grind_stevie-williams_sw.mov'],
#  ['kickflip',
#   'akihiko-gatongay',
#   False,
#   False,
#   'C:/Users/Braden/Projects/SkateboardAI/skateboard-tricks\\kickflip_akihiko-gatongay.mov'],
#  ['kickflip',
#   'akihiko-gatongay',
#   False,
#   False,
#   'C:/Users/Braden/Projects/SkateboardAI/skateboard-tricks\\kickflip_akihiko-gatongay_2.mov'],
#  ['kickflip',
#   'ben-gore',
#   False,
#   False,
#   'C:/Users/Braden/Projects/SkateboardAI/skateboard-tricks\\kickflip_ben-gore.mov'],
#  ['kickflip',
#   'ben-gore',
#   False,
#   False,
#   'C:/Users/Braden/Projects/SkateboardAI/skateboard-tricks\\kickflip_ben-gore_2.mov'],
#  ['kickflip',
#   'braden-starcher',
#   False,
#   False,
#   'C:/Users/Braden/Projects/SkateboardAI/skateboard-tricks\\kickflip_braden-starcher_1.mp4'],
#  ['kickflip',
#   'braden-starcher',
#   False,
#   False,
#   'C:/Users/Braden/Projects/SkateboardAI/skateboard-tricks\\kickflip_braden-starcher_2.mp4'],
#  ['kickflip',
#   'braden-starcher',
#   False,
#   False,
#   'C:/Users/Braden/Projects/SkateboardAI/skateboard-tricks\\kickflip_braden-starcher_3.mp4'],
#  ['kickflip',
#   'braden-starcher',
#   False,
#   False,
#   'C:/Users/Braden/Projects/SkateboardAI/skateboard-tricks\\kickflip_braden-starcher_4.mp4'],
#  ['kickflip',
#   'braden-starcher',
#   False,
#   False,
#   'C:/Users/Braden/Projects/SkateboardAI/skateboard-tricks\\kickflip_braden-starcher_5.mp4'],
#  ['kickflip',
#   'clint-walker',
#   False,
#   False,
#   'C:/Users/Braden/Projects/SkateboardAI/skateboard-tricks\\kickflip_clint-walker.mov'],
#  ['kickflip',
#   'clint-walker',
#   False,
#   False,
#   'C:/Users/Braden/Projects/SkateboardAI/skateboard-tricks\\kickflip_clint-walker_2.mov'],
#  ['kickflip',
#   'dylan-jaeb',
#   False,
#   True,
#   'C:/Users/Braden/Projects/SkateboardAI/skateboard-tricks\\kickflip_dylan-jaeb_slow-mo.mov'],
#  ['kickflip',
#   'dylan-jaeb',
#   False,
#   True,
#   'C:/Users/Braden/Projects/SkateboardAI/skateboard-tricks\\kickflip_dylan-jaeb_slow-mo_2.mov'],
#  ['kickflip',
#   'dylan-jaeb',
#   True,
#   True,
#   'C:/Users/Braden/Projects/SkateboardAI/skateboard-tricks\\kickflip_dylan-jaeb_sw_slow-mo.mov'],
#  ['kickflip',
#   'eric-koston',
#   False,
#   False,
#   'C:/Users/Braden/Projects/SkateboardAI/skateboard-tricks\\kickflip_eric-koston.mov'],
#  ['kickflip',
#   'hyun-kummer',
#   False,
#   False,
#   'C:/Users/Braden/Projects/SkateboardAI/skateboard-tricks\\kickflip_hyun-kummer.mov'],
#  ['kickflip',
#   'hyun-kummer',
#   False,
#   False,
#   'C:/Users/Braden/Projects/SkateboardAI/skateboard-tricks\\kickflip_hyun-kummer_2.mov'],
#  ['kickflip',
#   'kelly-hart',
#   False,
#   False,
#   'C:/Users/Braden/Projects/SkateboardAI/skateboard-tricks\\kickflip_kelly-hart.mov'],
#  ['kickflip',
#   'lavar-mcbride',
#   False,
#   False,
#   'C:/Users/Braden/Projects/SkateboardAI/skateboard-tricks\\kickflip_lavar-mcbride.mov'],
#  ['kickflip',
#   'leo-romero',
#   False,
#   False,
#   'C:/Users/Braden/Projects/SkateboardAI/skateboard-tricks\\kickflip_leo-romero.mov'],
#  ['kickflip',
#   'leo-romero',
#   False,
#   False,
#   'C:/Users/Braden/Projects/SkateboardAI/skateboard-tricks\\kickflip_leo-romero_2.mov'],
#  ['kickflip',
#   'leo-romero',
#   False,
#   False,
#   'C:/Users/Braden/Projects/SkateboardAI/skateboard-tricks\\kickflip_leo-romero_3.mov'],
#  ['kickflip',
#   'leo-romero',
#   False,
#   False,
#   'C:/Users/Braden/Projects/SkateboardAI/skateboard-tricks\\kickflip_leo-romero_4.mov'],
#  ['kickflip',
#   'leo-romero',
#   False,
#   False,
#   'C:/Users/Braden/Projects/SkateboardAI/skateboard-tricks\\kickflip_leo-romero_5.mov'],
#  ['kickflip',
#   'mitchi-brusco',
#   False,
#   False,
#   'C:/Users/Braden/Projects/SkateboardAI/skateboard-tricks\\kickflip_mitchi-brusco.mov'],
#  ['kickflip',
#   'mitchi-brusco',
#   False,
#   False,
#   'C:/Users/Braden/Projects/SkateboardAI/skateboard-tricks\\kickflip_mitchi-brusco_2.mov'],
#  ['kickflip',
#   'mitchi-brusco',
#   False,
#   False,
#   'C:/Users/Braden/Projects/SkateboardAI/skateboard-tricks\\kickflip_mitchi-brusco_3.mov'],
#  ['kickflip',
#   'stevie-williams',
#   True,
#   False,
#   'C:/Users/Braden/Projects/SkateboardAI/skateboard-tricks\\kickflip_stevie-williams_sw.mov'],
#  ['kickflip',
#   'tony-hawk',
#   False,
#   True,
#   'C:/Users/Braden/Projects/SkateboardAI/skateboard-tricks\\kickflip_tony-hawk_slow-mo.mov'],
#  ['kickflip',
#   'unknown',
#   False,
#   False,
#   'C:/Users/Braden/Projects/SkateboardAI/skateboard-tricks\\kickflip_unknown.mov'],
#  ['ollie',
#   'ashton-hilliker',
#   False,
#   False,
#   'C:/Users/Braden/Projects/SkateboardAI/skateboard-tricks\\ollie_ashton-hilliker.mov'],
#  ['ollie',
#   'braden-starcher',
#   False,
#   False,
#   'C:/Users/Braden/Projects/SkateboardAI/skateboard-tricks\\ollie_braden-starcher_1.mp4'],
#  ['ollie',
#   'braden-starcher',
#   False,
#   False,
#   'C:/Users/Braden/Projects/SkateboardAI/skateboard-tricks\\ollie_braden-starcher_2.mp4'],
#  ['ollie',
#   'braden-starcher',
#   False,
#   False,
#   'C:/Users/Braden/Projects/SkateboardAI/skateboard-tricks\\ollie_braden-starcher_3.mp4'],
#  ['ollie',
#   'braden-starcher',
#   False,
#   False,
#   'C:/Users/Braden/Projects/SkateboardAI/skateboard-tricks\\ollie_braden-starcher_4.mp4'],
#  ['ollie',
#   'clint-walker',
#   False,
#   False,
#   'C:/Users/Braden/Projects/SkateboardAI/skateboard-tricks\\ollie_clint-walker.mov'],
#  ['ollie',
#   'clint-walker',
#   False,
#   False,
#   'C:/Users/Braden/Projects/SkateboardAI/skateboard-tricks\\ollie_clint-walker_2.mov'],
#  ['ollie',
#   'clint-walker',
#   False,
#   False,
#   'C:/Users/Braden/Projects/SkateboardAI/skateboard-tricks\\ollie_clint-walker_3.mov'],
#  ['ollie',
#   'gavin-botger',
#   False,
#   True,
#   'C:/Users/Braden/Projects/SkateboardAI/skateboard-tricks\\ollie_gavin-botger_slow-mo.mov'],
#  ['ollie',
#   'hyun-kummer',
#   False,
#   False,
#   'C:/Users/Braden/Projects/SkateboardAI/skateboard-tricks\\ollie_hyun-kummer.mov'],
#  ['ollie',
#   'hyun-kummer',
#   False,
#   False,
#   'C:/Users/Braden/Projects/SkateboardAI/skateboard-tricks\\ollie_hyun-kummer_2.mov'],
#  ['ollie',
#   'jaws',
#   False,
#   False,
#   'C:/Users/Braden/Projects/SkateboardAI/skateboard-tricks\\ollie_jaws.mov'],
#  ['ollie',
#   'matt-weitman',
#   False,
#   False,
#   'C:/Users/Braden/Projects/SkateboardAI/skateboard-tricks\\ollie_matt-weitman.mov'],
#  ['ollie',
#   'mitchie-brusco',
#   False,
#   False,
#   'C:/Users/Braden/Projects/SkateboardAI/skateboard-tricks\\ollie_mitchie-brusco.mov'],
#  ['ollie',
#   'vincent-basille',
#   False,
#   False,
#   'C:/Users/Braden/Projects/SkateboardAI/skateboard-tricks\\ollie_vincent-basille.mov'],
#  ['ollie',
#   'vincent-basille',
#   False,
#   False,
#   'C:/Users/Braden/Projects/SkateboardAI/skateboard-tricks\\ollie_vincent-basille_2.mov'],
#  ['ollie',
#   'vincent-basille',
#   False,
#   False,
#   'C:/Users/Braden/Projects/SkateboardAI/skateboard-tricks\\ollie_vincent-basille_3.mov'],
#  ['ollie',
#   'vincent-basille',
#   False,
#   False,
#   'C:/Users/Braden/Projects/SkateboardAI/skateboard-tricks\\ollie_vincent-basille_4.mov']]

# %%
trick_names = ['360-flip', 'crooked-grind' 'bs-flip', 'kickflip','ollie']

tricks_df = pd.DataFrame(tricks_data)
tricks_df = tricks_df.rename(columns={0: 'trick', 1: 'skater', 2: 'switch', 3: 'slowmo', 4: 'filepath'})
# tricks_df
categories = tricks_df['trick'].value_counts().index
counts = tricks_df['trick'].value_counts().values
plt.title("Trick data")
plt.bar(categories, counts, width=0.5)
# Out:
# <BarContainer object of 5 artists>

# %% [markdown]
# ### SkateboardingDataset

# %%
import torch
from skimage import io, transform 
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, utils
import cv2
import sys

# %%
class SkateboardDataset(Dataset): 
    def __init__(self, video_paths, transform=None):
        # parse filenames, store video paths
        self.video_paths = video_paths
        self.transform = transform
        
    def __len__(self): 
        # Return number of videos in dataset
        
        
    def __getitem(self, idx): 
        # load video, sample frames, return (frames, label)
        if torch.is_tensor(idx): 
            idx = idx.tolist()

# %%
video_paths = "./skateboard_dataset"
dataset = SkateboardDataset(video_paths)

# %%
cap = cv2.VideoCapture('./skateboard_dataset/360-flip_akihiko-gatangay.mov')
frames = []
if not cap.isOpened(): 
    print("Error: could not open video.")
else: 
    while cap.isOpened(): 
        ret, frame = cap.read() 
        # if frame is read correctly ret is True 
        if not ret: 
            print("Can't receive frame (stream end?). Exiting...")
            break 
        frames.append(frame)
cap.release()
print(len(frames))
# Out:
# Can't receive frame (stream end?). Exiting...
# 25

# %%
sys.getsizeof(frame)
# Out:
# 16

# %%
plt.imshow(frames[1])
